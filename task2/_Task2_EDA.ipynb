# %% [markdown]
# # Task 2: Exploratory Data Analysis

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()

# %%
df.info()
df.describe()

# %% [markdown]
# Visualization and correlation analysis.
